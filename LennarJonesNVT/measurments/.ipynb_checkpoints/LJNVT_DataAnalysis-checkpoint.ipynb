# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
averagePressures = {}
for i in range(20):
    


meas = pd.read_csv("measurments1.csv")
meas.AveragePressure.plot()
print(f"Mean average pressure:{meas.AveragePressure.mean()}")
# Out:
# Mean average pressure:0.09472074400010001

# %%
meas.AveragePressure[meas.Step % 100 == 0].plot()
# Out:
# <Axes: >
