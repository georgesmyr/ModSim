# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
meas = pd.read_csv("measurments.csv")
meas.AveragePressure.plot()
print(f"Mean average pressure:{meas.AveragePressure.mean()}")
# Out:
# Mean average pressure:0.09525592518777364

# %%
meas.AveragePressure[meas.Step % 100 == 0].plot()
# Out:
# <Axes: >

# %%
meas
# Out:
#       Step  AveragePressure  MuExcess
# 0        0         0.048222 -0.095078
# 1        1         0.026389 -0.478868
# 2        2         0.028174 -0.789800
# 3        3         0.050052 -1.341670
# 4        4         0.033152 -0.220036
# ...    ...              ...       ...
# 5205  5205        -0.008750 -0.062538
# 5206  5206         0.085709 -0.026316
# 5207  5207         0.067811 -0.060567
# 5208  5208         0.128725 -0.262037
# 5209  5209         0.055847 -0.098505
#
# [5210 rows x 3 columns]

# %%
meas = pd.read_csv("measurments0.500000.csv")
meas.AveragePressure.plot()
print(f"Mean average pressure:{meas.AveragePressure.mean()}")
# Out:
# Mean average pressure:0.7981808689999998

# %%
avgpressures = {0.1: 0.19656647999999952,
                0.2: 0.3906687239999992,
                0.3: 0.58824063,
                0.4: 0.7981808689999998
               }

# %%
s = "measurments1.csv"
