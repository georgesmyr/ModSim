# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
energies = pd.read_csv('energies.csv').set_index("time")
energies.head()
energies.plot()
# Out:
# <Axes: xlabel='time'>

# %%
# Out:
# /var/folders/p9/x0yk1mfj5pb1sg43mz3458hr0000gn/T/ipykernel_20265/3569945568.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
